# %% [markdown]
# # Generate images with original image and CAM.
# The CAM is 2D, but images are 3D. So we only select the center slice of original image and comibne it with CAM

# %%
from medutils.medutils import load_itk, save_itk
import matplotlib.pyplot as plt

# %%
data_dir = "/home/jjia/data/AIMIRA/data"
cam_0_dir = data_dir + "/fold2_cate0_mtgradcam/fold2_cate0_mtgradcam/normTrue_rm0False_all0.05"
cam_1_dir = data_dir + "/fold2_cate1_mtgradcam/fold2_cate1_mtgradcam/normTrue_rm0False_all0.05"
cam_0_fpath = cam_0_dir + '/fold2_0_p0.nii.gz'
cam_1_fpath = cam_1_dir + "/fold2_0_p0.nii.gz"

cam_0 = load_itk(cam_0_fpath)
cam_1 = load_itk(cam_1_fpath)

# %%
cam = cam_1 + cam_0

# %%
plt.imshow(cam_1[:,:,4])
plt.colorbar()
plt.show()

# %%
plt.imshow(cam_0[:,:,4])
plt.colorbar()
plt.show()

# %%
plt.imshow(cam[:,:,4], cmap='jet')
plt.colorbar()
plt.show()
